# %%
s='hello'
n=3
def print_n(s, n):
    if n <= 0:
        return
    print(s)
    print_n(s, n-1)

# %%
print(type(s))
print(s)
# Out:
# <class 'str'>
# hello

# %%
import numpy as np
numpy.__version__
# Out:
# '1.20.3'

# %%
# ------- file: myplot.py ------
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show()
